# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
import matplotlib.pyplot as plt

# %%
a=pd.read_csv("apple.csv")
a
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
#                                 Acidity Quality
# 0                          -0.491590483    good
# 1                          -0.722809367    good
# 2                           2.621636473     bad
# 3                           0.790723217    good
# 4                           0.501984036    good
# ...                                 ...     ...
# 3996                        1.854235285    good
# 3997                       -1.334611391     bad
# 3998                       -2.229719806    good
# 3999                        1.599796456    good
# 4000  Created_by_Nidula_Elgiriyewithana     NaN
#
# [4001 rows x 9 columns]

# %%
#Drop column A_id

b=a.drop(['A_id'],axis=1)
b
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...        ...       ...        ...          ...        ...       ...
# 3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000       NaN       NaN        NaN          NaN        NaN       NaN
#
#                                 Acidity Quality
# 0                          -0.491590483    good
# 1                          -0.722809367    good
# 2                           2.621636473     bad
# 3                           0.790723217    good
# 4                           0.501984036    good
# ...                                 ...     ...
# 3996                        1.854235285    good
# 3997                       -1.334611391     bad
# 3998                       -2.229719806    good
# 3999                        1.599796456    good
# 4000  Created_by_Nidula_Elgiriyewithana     NaN
#
# [4001 rows x 8 columns]

# %%
#Drop last row
b=b.drop(index=4000,axis=0)
b
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...        ...       ...        ...          ...        ...       ...
# 3995  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity Quality
# 0     -0.491590483    good
# 1     -0.722809367    good
# 2      2.621636473     bad
# 3      0.790723217    good
# 4      0.501984036    good
# ...            ...     ...
# 3995   0.137784369     bad
# 3996   1.854235285    good
# 3997  -1.334611391     bad
# 3998  -2.229719806    good
# 3999   1.599796456    good
#
# [4000 rows x 8 columns]

# %%
b.head()
# Out:
#        Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %%
#Split data

x=b.drop(["Quality"],axis=1)
y=b["Quality"]
display(x)
display(y)
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...        ...       ...        ...          ...        ...       ...
# 3995  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity
# 0     -0.491590483
# 1     -0.722809367
# 2      2.621636473
# 3      0.790723217
# 4      0.501984036
# ...            ...
# 3995   0.137784369
# 3996   1.854235285
# 3997  -1.334611391
# 3998  -2.229719806
# 3999   1.599796456
#
# [4000 rows x 7 columns]
# 0       good
# 1       good
# 2        bad
# 3       good
# 4       good
#         ...
# 3995     bad
# 3996    good
# 3997     bad
# 3998    good
# 3999    good
# Name: Quality, Length: 4000, dtype: object

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)
display(x_test)
display(x_train)
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 3846 -0.380778 -2.505775  -2.581863     0.294634   3.468444  2.277529
# 848  -1.097169  1.375531  -0.684202     1.990824   2.508599 -3.885318
# 1658 -0.377568  1.118196   0.429448     2.384570  -1.249722 -0.302082
# 3415 -1.733816  0.351822   1.870895     2.979015  -2.047081 -1.690429
# 3678  0.592846 -0.967983  -1.424665     2.620696  -0.533478  0.413023
# ...        ...       ...        ...          ...        ...       ...
# 1512  0.251275 -1.685525  -2.482656    -0.625555   3.002715 -1.295302
# 1763  2.495227 -2.059803   0.232831     0.214407   3.564176 -1.102142
# 2608 -1.356046  0.470946  -1.195250     1.112280   2.172756  0.780758
# 265   0.778344  0.750074  -2.106504     0.250450   1.194048 -0.297127
# 3639  1.048382 -1.839771  -1.376466     3.183665   0.253454 -1.620283
#
#            Acidity
# 3846   3.447199193
# 848    0.894076504
# 1658  -0.687521898
# 3415   0.101005434
# 3678  -0.140260908
# ...            ...
# 1512    5.26838182
# 1763   3.368661424
# 2608    2.00555776
# 265    1.338008142
# 3639  -0.024782906
#
# [800 rows x 7 columns]
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 1617 -1.178036  0.089910  -0.559431     1.440344   0.127449  0.710499
# 3157  1.625461 -1.534990  -5.016761     0.309944   1.110964  2.913674
# 2960 -3.640411 -0.284995   1.035446     0.197993   1.107829  0.600651
# 1189  1.102581 -2.189710  -1.318490     1.908255  -3.674468  0.095646
# 2676 -6.710169  1.035163  -0.443713    -1.155560   2.526025  3.678178
# ...        ...       ...        ...          ...        ...       ...
# 3606 -0.643458 -0.107457  -1.041029     2.152756   0.592408 -2.736255
# 1608 -1.167452 -2.279614   1.242500     2.690916   0.019712  1.536990
# 2541 -3.824104 -0.653506   2.017481    -0.650462  -0.267903 -3.810387
# 2575  2.180187 -1.511394  -2.686208    -2.396660   1.132262  2.050631
# 3240  0.101584 -0.315758  -1.972458     0.584135   2.133440 -0.009840
#
#            Acidity
# 1617   0.456268981
# 3157  -0.746742282
# 2960  -1.073124668
# 1189  -1.164808614
# 2676   -0.82028043
# ...            ...
# 3606  -1.824904108
# 1608   1.455562203
# 2541  -0.293752288
# 2575  -0.228236467
# 3240   2.662200873
#
# [3200 rows x 7 columns]

# %%
dt_classifier=DecisionTreeClassifier()
dt_classifier.fit(x_train,y_train)
dt_predictions=dt_classifier.predict(x_test)
print("Decision_tree accuracy: ",accuracy_score(y_test,dt_predictions))
print("\nDecision_tree confusion matrix: \n",confusion_matrix(y_test,dt_predictions))
print("\nDecision_tree classification report: \n",classification_report(y_test,dt_predictions))
# Out:
# Decision_tree accuracy:  0.80625
#
# Decision_tree confusion matrix:
#  [[328  79]
#  [ 76 317]]
#
# Decision_tree classification report:
#                precision    recall  f1-score   support
#
#          bad       0.81      0.81      0.81       407
#         good       0.80      0.81      0.80       393
#
#     accuracy                           0.81       800
#    macro avg       0.81      0.81      0.81       800
# weighted avg       0.81      0.81      0.81       800

# %%
nb_classifier=GaussianNB()
nb_classifier.fit(x_train,y_train)
nb_predictions=nb_classifier.predict(x_test)
print("Naive bayes accuracy: ",accuracy_score(y_test,nb_predictions))
print("\nNaive bayes confusion matrix: \n",confusion_matrix(y_test,nb_predictions))
print("\nNaive bayes classification report: \n",classification_report(y_test,nb_predictions))
# Out:
# Naive bayes accuracy:  0.75125
#
# Naive bayes confusion matrix:
#  [[310  97]
#  [102 291]]
#
# Naive bayes classification report:
#                precision    recall  f1-score   support
#
#          bad       0.75      0.76      0.76       407
#         good       0.75      0.74      0.75       393
#
#     accuracy                           0.75       800
#    macro avg       0.75      0.75      0.75       800
# weighted avg       0.75      0.75      0.75       800

# %%
svm_classifier=SVC()
svm_classifier.fit(x_train,y_train)
svm_predictions=svm_classifier.predict(x_test)
print("svm accuracy: ",accuracy_score(y_test,svm_predictions))
print("\nsvm confusion matrix: \n",confusion_matrix(y_test,svm_predictions))
print("\nsvm classification report: \n",classification_report(y_test,svm_predictions))
# Out:
# svm accuracy:  0.90875
#
# svm confusion matrix:
#  [[364  43]
#  [ 30 363]]
#
# svm classification report:
#                precision    recall  f1-score   support
#
#          bad       0.92      0.89      0.91       407
#         good       0.89      0.92      0.91       393
#
#     accuracy                           0.91       800
#    macro avg       0.91      0.91      0.91       800
# weighted avg       0.91      0.91      0.91       800

# %%
rf_classifier=RandomForestClassifier()
rf_classifier.fit(x_train,y_train)
rf_predictions=rf_classifier.predict(x_test)
print("random forest accuracy: ",accuracy_score(y_test,rf_predictions))
print("\nrandom forest confusion matrix: \n",confusion_matrix(y_test,rf_predictions))
print("\nrandom forest classification report: \n",classification_report(y_test,rf_predictions))
# Out:
# random forest accuracy:  0.8825
#
# random forest confusion matrix:
#  [[357  50]
#  [ 44 349]]
#
# random forest classification report:
#                precision    recall  f1-score   support
#
#          bad       0.89      0.88      0.88       407
#         good       0.87      0.89      0.88       393
#
#     accuracy                           0.88       800
#    macro avg       0.88      0.88      0.88       800
# weighted avg       0.88      0.88      0.88       800

# %%
clf=DecisionTreeClassifier()
clf.fit(x,y)
plt.figure()
plot_tree(clf,filled=True)
plt.show()
